# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
BME280 = pd.read_csv('BME280.csv')

# %%
BME280
# Out:
#                         dateTime  temperature  pressure  humidity  altitude
# 0     2021-06-09 00:00:02.863480        35.67   99302.0      50.0    169.78
# 1     2021-06-09 00:00:12.897674        35.67   99298.0      50.0    170.12
# 2     2021-06-09 00:00:22.932414        35.68   99296.0      50.0    170.28
# 3     2021-06-09 00:00:32.967237        35.67   99296.0      50.0    170.28
# 4     2021-06-09 00:00:43.002139        35.68   99299.0      50.0    170.03
# ...                          ...          ...       ...       ...       ...
# 5089  2021-06-09 14:13:03.188927        30.75   99765.0      64.0    130.68
# 5090  2021-06-09 14:13:13.223645        30.76   99767.0      64.0    130.51
# 5091  2021-06-09 14:13:23.258325        30.76   99769.0      64.0    130.34
# 5092  2021-06-09 14:13:33.293033        30.77   99769.0      64.0    130.34
# 5093  2021-06-09 14:13:43.327608        30.76   99769.0      64.0    130.34
#
# [5094 rows x 5 columns]

# %%
fig = plt.figure(figsize=(10,8), dpi=80)
plt.subplot(2, 2, 1)
plt.plot(BME280.dateTime, BME280.temperature)
plt.xlabel('date/time')
plt.ylabel('temperature')
plt.subplot(2, 2, 2)
plt.plot(BME280.dateTime, BME280.pressure)
plt.xlabel('date/time')
plt.ylabel('pressure')
plt.subplot(2, 2, 3)
plt.plot(BME280.dateTime, BME280.humidity)
plt.xlabel('date/time')
plt.ylabel('humidity')
plt.subplot(2, 2, 4)
plt.plot(BME280.dateTime, BME280.altitude)
plt.xlabel('date/time')
plt.ylabel('altitude')
plt.show()

# %%
IP = pd.read_csv('IP.csv')

# %%
IP
# Out:
#                       dateTime         publicIp         localIp
# 0   2021-05-12 23:24:43.302727  129.110.242.173  192.168.20.121
# 1   2021-05-14 20:44:09.530530  129.110.242.173  192.168.20.121
# 2   2021-05-14 20:47:23.584828  129.110.242.173  192.168.20.121
# 3   2021-05-26 10:29:50.714791   107.77.197.165        10.0.4.2
# 4   2021-06-01 23:21:55.679721    107.77.199.70        10.0.4.2
# 5   2021-06-02 09:01:46.773605    107.77.198.40        10.0.4.2
# 6   2021-06-02 19:56:53.188368    107.77.198.40        10.0.4.2
# 7   2021-06-03 09:01:47.221298    107.77.198.40        10.0.4.2
# 8   2021-06-04 09:01:48.140693    107.77.196.94        10.0.4.2
# 9   2021-06-05 09:01:47.052176    107.77.196.94        10.0.4.2
# 10  2021-06-06 09:01:48.209190    107.77.196.94        10.0.4.2
# 11  2021-06-07 09:01:47.187854    107.77.196.94        10.0.4.2
# 12  2021-06-08 09:01:47.869330    107.77.196.94        10.0.4.2
# 13  2021-06-09 09:01:48.036841   107.77.200.201        10.0.4.2

# %%
fig = plt.figure(figsize=(25,13), dpi=50)
plt.subplot (1, 2, 1)
plt.plot(IP.dateTime, IP.publicIp)
plt.xlabel('date/time')
plt.ylabel('public IP')
plt.subplot(1, 2, 2)
plt.plot(IP.dateTime, IP.localIp)
plt.xlabel('date/time')
plt.ylabel('local IP')
plt.show()

# %%
SCD30 = pd.read_csv('SCD30.csv')

# %%
SCD30
# Out:
#                         dateTime  c02  temperature  humidity
# 0     2021-06-09 00:00:05.167288  396           36        50
# 1     2021-06-09 00:00:15.202053  395           36        50
# 2     2021-06-09 00:00:25.221390  395           36        50
# 3     2021-06-09 00:00:35.256226  395           36        50
# 4     2021-06-09 00:00:45.290957  394           36        50
# ...                          ...  ...          ...       ...
# 5131  2021-06-09 14:19:56.867399  427           31        63
# 5132  2021-06-09 14:20:06.886101  428           31        63
# 5133  2021-06-09 14:20:16.920985  427           31        63
# 5134  2021-06-09 14:20:26.955356  428           31        63
# 5135  2021-06-09 14:20:36.989905  427           31        63
#
# [5136 rows x 4 columns]

# %%
fig = plt.figure(figsize=(10,5), dpi=80)
plt.subplot (1, 3, 1)
plt.plot(SCD30.dateTime, SCD30.c02)
plt.xlabel('date/time')
plt.ylabel('c02')
plt.subplot(1, 3, 2)
plt.plot(SCD30.dateTime, SCD30.temperature)
plt.xlabel('date/time')
plt.ylabel('temperature')
plt.subplot(1, 3, 3)
plt.plot(SCD30.dateTime, SCD30.humidity)
plt.xlabel('date/time')
plt.ylabel('humidity')
plt.show()

# %%
MGS001 = pd.read_csv('MGS001.csv')

# %%
MGS001
# Out:
#                         dateTime   nh3   co     no2  c3h8   c4h10     ch4  \
# 0     2021-06-09 00:00:04.191679  0.07  0.0    4.69  0.89  854.51  561.31
# 1     2021-06-09 00:00:14.226188  0.07  0.0    4.69  0.89  854.51  561.31
# 2     2021-06-09 00:00:24.260852  0.07  0.0    4.60  0.87  825.60  545.14
# 3     2021-06-09 00:00:34.295680  0.07  0.0    4.73  0.91  884.85  578.18
# 4     2021-06-09 00:00:44.330510  0.07  0.0    4.60  0.87  825.60  545.14
# ...                          ...   ...  ...     ...   ...     ...     ...
# 5150  2021-06-09 14:23:06.534362  0.06  0.0    4.49  0.88  835.08  550.45
# 5151  2021-06-09 14:23:16.568758  0.06  0.0    4.49  0.88  844.72  555.84
# 5152  2021-06-09 14:23:26.603404  0.06  0.0    4.43  0.88  835.08  550.45
# 5153  2021-06-09 14:23:36.638484  0.06  0.0  261.09  0.78  707.30  478.05
# 5154  2021-06-09 14:23:46.673221  0.06  0.0  261.09  0.78  707.30  478.05
#
#                 h2  c2h5oh
# 0     8.064300e+02      0.81
# ...

# %%
fig = plt.figure(figsize=(12, 18), dpi=80)
plt.subplot (3, 3, 1)
plt.plot(MGS001.dateTime, MGS001.nh3)
plt.xlabel('date/time')
plt.ylabel('nh3')
plt.subplot (3, 3, 2)
plt.plot(MGS001.dateTime, MGS001.co)
plt.xlabel('date/time')
plt.ylabel('co')
plt.subplot(3, 3, 3)
plt.plot(MGS001.dateTime, MGS001.no2)
plt.xlabel('date/time')
plt.ylabel('no2')
plt.subplot(3, 3, 4)
plt.plot(MGS001.dateTime, MGS001.c3h8)
plt.xlabel('date/time')
plt.ylabel('c3h8')
plt.subplot(3, 3, 5)
plt.plot(MGS001.dateTime, MGS001.ch4)
plt.xlabel('date/time')
plt.ylabel('ch4')
plt.subplot(3, 3, 6)
plt.plot(MGS001.dateTime, MGS001.h2)
plt.xlabel('date/time')
plt.ylabel('h2')
plt.subplot(3, 3, 7)
plt.plot(MGS001.dateTime, MGS001.c2h5oh)
plt.xlabel('date/time')
plt.ylabel('c2h5oh')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-bffdf03ae8ae> in <module>
#      25 plt.ylabel('h2')
#      26 plt.subplot(3, 3, 7)
# ---> 27 plt.plot(MGS001.dateTime, MGS001.c2h5oh)
#      28 plt.xlabel('date/time')
#      29 plt.ylabel('c2h5oh')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'c2h5oh'

# %%
GUV001 = pd.read_csv('GUV001.csv')

# %%
GUV001
# Out:
#                         dateTime  uvLevel
# 0     2021-06-09 09:01:56.485158        0
# 1     2021-06-09 09:02:13.441137        0
# 2     2021-06-09 09:02:30.412420        0
# 3     2021-06-09 09:02:47.383737        0
# 4     2021-06-09 09:03:04.339472        0
# ...                          ...      ...
# 1103  2021-06-09 14:14:03.252740        0
# 1104  2021-06-09 14:14:20.239601        0
# 1105  2021-06-09 14:14:37.226871        0
# 1106  2021-06-09 14:14:54.214134        0
# 1107  2021-06-09 14:15:11.201629        0
#
# [1108 rows x 2 columns]

# %%
fig = plt.figure(figsize=(6, 8), dpi=80)
plt.subplot (1, 1, 1)
plt.plot(GUV001.dateTime, GUV001.uvLevel)
plt.xlabel('date/time')
plt.ylabel('uvLevel')
plt.show()

# %%
VEML6075 = pd.read_csv('VEML6075.csv')

# %%
VEML6075
# Out:
#                         dateTime  rawUVA  rawUVB  visibleCompensation  \
# 0     2021-06-09 09:01:49.555767       0       0                    0
# 1     2021-06-09 09:02:06.297285       0       0                    0
# 2     2021-06-09 09:02:23.253581       0       0                    0
# 3     2021-06-09 09:02:40.224549       0       0                    0
# 4     2021-06-09 09:02:57.180303       0       0                    0
# ...                          ...     ...     ...                  ...
# 1123  2021-06-09 14:19:35.839610     257     348                   48
# 1124  2021-06-09 14:19:52.811223     251     339                   47
# 1125  2021-06-09 14:20:09.798961     250     338                   46
# 1126  2021-06-09 14:20:26.785616     249     338                   46
# 1127  2021-06-09 14:20:43.773014     250     339                   47
#
#       irCompensation    uva     uvb  index
# 0                  0   0.00    0.00   0.00
# ...

# %%
fig = plt.figure(figsize=(8, 10), dpi=80)
plt.subplot (3, 3, 1)
plt.plot(VEML6075.dateTime, VEML6075.rawUVA)
plt.xlabel('date/time')
plt.ylabel('rawUVA')
plt.subplot(3, 3, 2)
plt.plot(VEML6075.dateTime, VEML6075.rawUVB)
plt.xlabel('date/time')
plt.ylabel('rawUVB')
plt.subplot(3, 3, 3)
plt.plot(VEML6075.dateTime, VEML6075.visibleCompensation)
plt.xlabel('date/time')
plt.ylabel('Visible Compensation')
plt.subplot(3, 3, 4)
plt.plot(VEML6075.dateTime, VEML6075.irCompensation)
plt.xlabel('date/time')
plt.ylabel('IR Compensation')
plt.subplot(3, 3, 5)
plt.plot(VEML6075.dateTime, VEML6075.uva)
plt.xlabel('date/time')
plt.ylabel('uva')
plt.subplot(3, 3, 6)
plt.plot(VEML6075.dateTime, VEML6075.uvb)
plt.xlabel('date/time')
plt.ylabel('uvb')
plt.subplot(3, 3, 7)
plt.plot(VEML6075.dateTime, VEML6075.index)
plt.xlabel('date/time')
plt.ylabel('index')
plt.show()

# %%
SI114X = pd.read_csv('SI114X.csv')

# %%
SI114X
# Out:
#                         dateTime  visible   ir    uv  proximity1  proximity2  \
# 0     2021-06-09 09:01:51.339374      261  254  0.02         201       20059
# 1     2021-06-09 09:02:08.295055      260  253  0.02         201       20060
# 2     2021-06-09 09:02:25.266705      261  255  0.02         202       20060
# 3     2021-06-09 09:02:42.222358      261  254  0.02         197       20065
# 4     2021-06-09 09:02:59.193741      260  254  0.02         201       20059
# ...                          ...      ...  ...   ...         ...         ...
# 1122  2021-06-09 14:19:20.849773      270  351  0.07         222       20683
# 1123  2021-06-09 14:19:37.837052      268  349  0.06         224       20659
# 1124  2021-06-09 14:19:54.808799      268  345  0.06         224       20641
# 1125  2021-06-09 14:20:11.796280      269  347  0.06         222       20639
# 1126  2021-06-09 14:20:28.783164      269  348  0.06         223       20653
#
#       proximity3
# 0              0
# ...

# %%
fig = plt.figure(figsize=(12, 12), dpi=80)
plt.subplot (2, 3, 1)
plt.plot(SI114X.dateTime, SI114X.visible)
plt.xlabel('date/time')
plt.ylabel('Visible')
plt.subplot(2, 3, 2)
plt.plot(SI114X.dateTime, SI114X.ir)
plt.xlabel('date/time')
plt.ylabel('IR')
plt.subplot(2, 3, 3)
plt.plot(SI114X.dateTime, SI114X.uv)
plt.xlabel('date/time')
plt.ylabel('UV')
plt.subplot(2, 3, 4)
plt.plot(SI114X.dateTime, SI114X.proximity1)
plt.xlabel('date/time')
plt.ylabel('proximity 1')
plt.subplot(2, 3, 5)
plt.plot(SI114X.dateTime, SI114X.proximity2)
plt.xlabel('date/time')
plt.ylabel('proximity 2')
plt.subplot(2, 3, 6)
plt.plot(SI114X.dateTime, SI114X.proximity3)
plt.xlabel('date/time')
plt.ylabel('proximity 3')
plt.show()

# %%
TSL2591 = pd.read_csv('TSL2591.csv')

# %%
TSL2591
# Out:
#                         dateTime  luminosity    ir   full  visible         lux
# 0     2021-06-09 09:01:48.318892       65539     1      3        2    0.072533
# 1     2021-06-09 09:02:05.274830       65539     1      3        2    0.072533
# 2     2021-06-09 09:02:22.246425       65539     1      3        2    0.072533
# 3     2021-06-09 09:02:39.217590       65538     1      2        1    0.027200
# 4     2021-06-09 09:02:56.173338       65539     1      3        2    0.072533
# ...                          ...         ...   ...    ...      ...         ...
# 1123  2021-06-09 14:19:34.832758   634478821  9681  24805    15124  501.640990
# 1124  2021-06-09 14:19:51.819959   615210460  9387  24028    14641  485.313930
# 1125  2021-06-09 14:20:08.792210   611540319  9331  23903    14572  483.264430
# 1126  2021-06-09 14:20:25.778903   619404980  9451  24244    14793  491.028960
# 1127  2021-06-09 14:20:42.766242   634478884  9681  24868    15187  504.547450
#
# [1128 rows x 6 columns]

# %%
fig = plt.figure(figsize=(11, 15), dpi=80)
plt.subplot (2, 3, 1)
plt.plot(TSL2591.dateTime, TSL2591.luminosity)
plt.xlabel('date/time')
plt.ylabel('luminosity')
plt.subplot(2, 3, 2)
plt.plot(TSL2591.dateTime, TSL2591.ir)
plt.xlabel('date/time')
plt.ylabel('IR')
plt.subplot(2, 3, 3)
plt.plot(TSL2591.dateTime, TSL2591.full)
plt.xlabel('date/time')
plt.ylabel('full')
plt.subplot(2, 3, 4)
plt.plot(TSL2591.dateTime, TSL2591.visible)
plt.xlabel('date/time')
plt.ylabel('visible')
plt.subplot(2, 3, 5)
plt.plot(TSL2591.dateTime, TSL2591.lux)
plt.xlabel('date/time')
plt.ylabel('lux')
plt.show()

# %%
GL001 = pd.read_csv('GL001.csv')

# %%
GL001
# Out:
#                         dateTime  lightLevel
# 0     2021-06-09 09:01:53.305305           0
# 1     2021-06-09 09:02:10.276644           0
# 2     2021-06-09 09:02:27.248104           0
# 3     2021-06-09 09:02:44.203823           0
# 4     2021-06-09 09:03:01.175024           0
# ...                          ...         ...
# 1098  2021-06-09 14:12:35.151904         734
# 1099  2021-06-09 14:12:52.139116         735
# 1100  2021-06-09 14:13:09.126366         738
# 1101  2021-06-09 14:13:26.113706         739
# 1102  2021-06-09 14:13:43.100979         734
#
# [1103 rows x 2 columns]

# %%
fig = plt.figure(figsize=(10, 12), dpi=80)
plt.subplot (1, 1, 1)
plt.plot(GL001.dateTime, GL001.lightLevel)
plt.xlabel('date/time')
plt.ylabel('light level')
plt.show()

# %%
BME280_2 = pd.read_csv('BME280_2.csv')

# %%
BME280_2
# Out:
#                         dateTime  temperature  pressure  humidity  altitude
# 0     2021-06-01 00:00:04.368139        22.06   99831.0     100.0    125.11
# 1     2021-06-01 00:00:14.411659        22.06   99828.0     100.0    125.37
# 2     2021-06-01 00:00:24.455402        22.05   99829.0     100.0    125.28
# 3     2021-06-01 00:00:34.498976        21.99   99832.0     100.0    125.03
# 4     2021-06-01 00:00:44.542699        21.86   99829.0     100.0    125.28
# ...                          ...          ...       ...       ...       ...
# 8584  2021-06-01 23:59:19.356325        22.77   99613.0      84.0    143.50
# 8585  2021-06-01 23:59:29.399425        22.75   99613.0      83.0    143.50
# 8586  2021-06-01 23:59:39.442517        22.70   99609.0      84.0    143.83
# 8587  2021-06-01 23:59:49.485596        22.77   99612.0      83.0    143.58
# 8588  2021-06-01 23:59:59.544249        22.78   99611.0      82.0    143.67
#
# [8589 rows x 5 columns]

# %%
fig = plt.figure(figsize=(10,8), dpi=80)
plt.subplot(2, 2, 1)
plt.plot(BME280_2.dateTime, BME280_2.temperature)
plt.xlabel('date/time')
plt.ylabel('temperature')
plt.subplot(2, 2, 2)
plt.plot(BME280_2.dateTime, BME280_2.pressure)
plt.xlabel('date/time')
plt.ylabel('pressure')
plt.subplot(2, 2, 3)
plt.plot(BME280_2.dateTime, BME280_2.humidity)
plt.xlabel('date/time')
plt.ylabel('humidity')
plt.subplot(2, 2, 4)
plt.plot(BME280_2.dateTime, BME280_2.altitude)
plt.xlabel('date/time')
plt.ylabel('altitude')
plt.show()

# %%
TMG3993 = pd.read_csv('TMG3993.csv')

# %%
TMG3993
# Out:
#                         dateTime  infraRed    red  green   blue  proximity
# 0     2021-06-09 09:01:50.332636       0.0    0.0    0.0    0.0         17
# 1     2021-06-09 09:02:07.288761       0.0    0.0    0.0    0.0         17
# 2     2021-06-09 09:02:24.259999       0.0    0.0    0.0    0.0         17
# 3     2021-06-09 09:02:41.231108       0.0    0.0    0.0    0.0         17
# 4     2021-06-09 09:02:58.186833       0.0    0.0    0.0    0.0         17
# ...                          ...       ...    ...    ...    ...        ...
# 1123  2021-06-09 14:19:36.830629    1654.0  684.0  689.0  633.0         17
# 1124  2021-06-09 14:19:53.817838    1604.0  662.0  669.0  615.0         17
# 1125  2021-06-09 14:20:10.805243    1587.0  654.0  663.0  610.0         17
# 1126  2021-06-09 14:20:27.792161    1605.0  662.0  671.0  618.0         18
# 1127  2021-06-09 14:20:44.779664    1644.0  678.0  686.0  632.0         17
#
# [1128 rows x 6 columns]

# %%
fig = plt.figure(figsize=(10,8), dpi=80)
plt.subplot(2, 3, 1)
plt.plot(TMG3993.dateTime, TMG3993.infraRed)
plt.xlabel('date/time')
plt.ylabel('infraRed')
plt.subplot(2, 3, 2)
plt.plot(TMG3993.dateTime, TMG3993.red)
plt.xlabel('date/time')
plt.ylabel('red')
plt.subplot(2, 3, 3)
plt.plot(TMG3993.dateTime, TMG3993.green)
plt.xlabel('date/time')
plt.ylabel('green')
plt.subplot(2, 3, 4)
plt.plot(TMG3993.dateTime, TMG3993.blue)
plt.xlabel('date/time')
plt.ylabel('green')
plt.subplot(2, 3, 5)
plt.plot(TMG3993.dateTime, TMG3993.proximity)
plt.xlabel('date/time')
plt.ylabel('proximity')
plt.show()

# %%
APDS9002 = pd.read_csv('APDS9002.csv')

# %%
APDS9002
# Out:
#                         dateTime  luminance  voltage  raw
# 0     2021-06-09 09:01:57.492159       1.01     0.00    0
# 1     2021-06-09 09:02:14.463805       1.01     0.00    0
# 2     2021-06-09 09:02:31.419443       1.01     0.00    0
# 3     2021-06-09 09:02:48.390779       1.01     0.00    0
# 4     2021-06-09 09:03:05.346447       1.01     0.00    0
# ...                          ...        ...      ...  ...
# 1097  2021-06-09 14:12:22.351500     146.21     0.55  113
# 1098  2021-06-09 14:12:39.338766     146.21     0.55  113
# 1099  2021-06-09 14:12:56.325956     142.45     0.54  110
# 1100  2021-06-09 14:13:13.313259     141.20     0.53  109
# 1101  2021-06-09 14:13:30.300527     144.96     0.55  112
#
# [1102 rows x 4 columns]

# %%
fig = plt.figure(figsize=(10,8), dpi=80)
plt.subplot(1, 3, 1)
plt.plot(APDS9002.dateTime, APDS9002.luminance)
plt.xlabel('date/time')
plt.ylabel('luminance')
plt.subplot(1, 3, 2)
plt.plot(APDS9002.dateTime, APDS9002.voltage)
plt.xlabel('date/time')
plt.ylabel('voltage')
plt.subplot(1, 3, 3)
plt.plot(APDS9002.dateTime, APDS9002.raw)
plt.xlabel('date/time')
plt.ylabel('raw')
plt.show()

# %%
SKYCAM_002 = pd.read_csv('SKYCAM_002.csv')

# %%
SKYCAM_002
# Out:
#                        dateTime  cloudPecentage      allRed    allGreen  \
# 0    2021-06-09 00:02:03.712810       99.200846  155.589245  143.201263
# 1    2021-06-09 00:04:06.250874       99.208659  152.455055  142.217923
# 2    2021-06-09 00:06:04.489238       99.082357  153.079043  141.694535
# 3    2021-06-09 00:12:04.569126       99.230469  153.929814  141.522601
# 4    2021-06-09 00:14:03.554166       99.235026  155.551305  144.126120
# ..                          ...             ...         ...         ...
# 313  2021-06-09 14:04:06.380738       99.692383  147.926774  137.222217
# 314  2021-06-09 14:06:03.286684       99.834635  143.500967  132.572503
# 315  2021-06-09 14:08:06.136238       99.913411  148.071488  135.409193
# 316  2021-06-09 14:12:03.440418       99.887695  145.304303  132.862796
# 317  2021-06-09 14:18:03.968908       99.844401  150.358704  138.435941
#
#         allBlue     skyRed   skyGreen     skyBlue    cloudRed  cloudGreen  \
# ...

# %%
fig = plt.figure(figsize=(10,8), dpi=80)
plt.subplot(5, 2, 1)
plt.plot(SKYCAM_002.dateTime, SKYCAM_002.cloudPecentage)
plt.xlabel('date/time')
plt.ylabel('cloud percentage')
plt.subplot(5, 2, 2)
plt.plot(SKYCAM_002.dateTime, SKYCAM_002.allRed)
plt.xlabel('date/time')
plt.ylabel('all red')
plt.subplot(5, 2, 3)
plt.plot(SKYCAM_002.dateTime, SKYCAM_002.allGreen)
plt.xlabel('date/time')
plt.ylabel('all green')
plt.subplot(5, 2, 4)
plt.plot(SKYCAM_002.dateTime, SKYCAM_002.allBlue)
plt.xlabel('date/time')
plt.ylabel('all blue')
plt.subplot(5, 2, 5)
plt.plot(SKYCAM_002.dateTime, SKYCAM_002.allRed)
plt.xlabel('date/time')
plt.ylabel('all red')
plt.subplot(5, 2, 6)
plt.plot(SKYCAM_002.dateTime, SKYCAM_002.allGreen)
plt.xlabel('date/time')
plt.ylabel('all green')
plt.subplot(5, 2, 7)
plt.plot(SKYCAM_002.dateTime, SKYCAM_002.skyBlue)
plt.xlabel('date/time')
plt.ylabel('sky blue')
plt.subplot(5, 2, 8)
plt.plot(SKYCAM_002.dateTime, SKYCAM_002.cloudRed)
plt.xlabel('date/time')
plt.ylabel('cloud red')
plt.subplot(5, 2, 9)
plt.plot(SKYCAM_002.dateTime, SKYCAM_002.cloudGreen)
plt.xlabel('date/time')
plt.ylabel('cloud green')
plt.subplot(5, 2, 10)
plt.plot(SKYCAM_002.dateTime, SKYCAM_002.cloudBlue)
plt.xlabel('date/time')
plt.ylabel('cloud blue')
plt.show()

# %%
SKYCAM003 = pd.read_csv('SKYCAM003.csv')

# %%
SKYCAM003
# Out:
#                        dateTime  cloudPecentage      allRed    allGreen  \
# 0    2021-06-09 00:00:03.677120       99.352214  153.008366  141.021533
# 1    2021-06-09 00:02:05.862999       99.178711  155.588490  143.035964
# 2    2021-06-09 00:06:06.106973       99.101237  153.213177  142.191800
# 3    2021-06-09 00:08:04.839094       99.105143  151.060745  139.518379
# 4    2021-06-09 00:10:04.087264       99.357422  150.536416  138.339678
# ..                          ...             ...         ...         ...
# 384  2021-06-09 14:12:05.354928       99.891276  145.666107  133.361872
# 385  2021-06-09 14:14:03.650919       99.922201  148.509847  135.332633
# 386  2021-06-09 14:16:04.168519       99.826497  146.248158  134.499814
# 387  2021-06-09 14:18:06.044734       99.858073  150.807223  138.825456
# 388  2021-06-09 14:20:05.475320       99.922201  149.513346  136.258779
#
#         allBlue     skyRed   skyGreen     skyBlue    cloudRed  cloudGreen  \
# ...

# %%
fig = plt.figure(figsize=(10,8), dpi=80)
plt.subplot(5, 2, 1)
plt.plot(SKYCAM003.dateTime, SKYCAM003.cloudPecentage)
plt.xlabel('date/time')
plt.ylabel('cloud percentage')
plt.subplot(5, 2, 2)
plt.plot(SKYCAM003.dateTime, SKYCAM003.allRed)
plt.xlabel('date/time')
plt.ylabel('all red')
plt.subplot(5, 2, 3)
plt.plot(SKYCAM003.dateTime, SKYCAM003.allGreen)
plt.xlabel('date/time')
plt.ylabel('all green')
plt.subplot(5, 2, 4)
plt.plot(SKYCAM003.dateTime, SKYCAM003.allBlue)
plt.xlabel('date/time')
plt.ylabel('all blue')
plt.subplot(5, 2, 5)
plt.plot(SKYCAM003.dateTime, SKYCAM003.allRed)
plt.xlabel('date/time')
plt.ylabel('all red')
plt.subplot(5, 2, 6)
plt.plot(SKYCAM003.dateTime, SKYCAM003.allGreen)
plt.xlabel('date/time')
plt.ylabel('all green')
plt.subplot(5, 2, 7)
plt.plot(SKYCAM003.dateTime, SKYCAM003.skyBlue)
plt.xlabel('date/time')
plt.ylabel('sky blue')
plt.subplot(5, 2, 8)
plt.plot(SKYCAM003.dateTime, SKYCAM003.cloudRed)
plt.xlabel('date/time')
plt.ylabel('cloud red')
plt.subplot(5, 2, 9)
plt.plot(SKYCAM003.dateTime, SKYCAM003.cloudGreen)
plt.xlabel('date/time')
plt.ylabel('cloud green')
plt.subplot(5, 2, 10)
plt.plot(SKYCAM003.dateTime, SKYCAM003.cloudBlue)
plt.xlabel('date/time')
plt.ylabel('cloud blue')
plt.show()

# %%
AS7262 = pd.read_csv('AS7262.csv')

# %%
AS7262
# Out:
#                         dateTime  temperature  violetPre  bluePre  greenPre  \
# 0     2021-06-09 09:02:03.948001           30          0        0         0
# 1     2021-06-09 09:02:20.904516           30          0        0         0
# 2     2021-06-09 09:02:37.875291           30          0        0         0
# 3     2021-06-09 09:02:54.831067           30          0        0         0
# 4     2021-06-09 09:03:11.802272           31          0        0         0
# ...                          ...          ...        ...      ...       ...
# 1097  2021-06-09 14:12:28.823423           32        404      474       751
# 1098  2021-06-09 14:12:45.810615           32        403      472       751
# 1099  2021-06-09 14:13:02.797914           32        404      472       759
# 1100  2021-06-09 14:13:19.785181           32        410      480       771
# 1101  2021-06-09 14:13:36.772403           32        411      483       775
#
# ...

# %%
fig = plt.figure(figsize=(10,8), dpi=80)
plt.subplot(4, 4, 1)
plt.plot(AS7262.dateTime, AS7262.temperature)
plt.xlabel('date/time')
plt.ylabel('temperature')
plt.subplot(4, 4, 2)
plt.plot(AS7262.dateTime, AS7262.violetPre)
plt.xlabel('date/time')
plt.ylabel('violetpre')
plt.subplot(4, 4, 3)
plt.plot(AS7262.dateTime, AS7262.bluePre)
plt.xlabel('date/time')
plt.ylabel('bluePre')
plt.subplot(4, 4, 4)
plt.plot(AS7262.dateTime, AS7262.greenPre)
plt.xlabel('date/time')
plt.ylabel('greenPre')
plt.subplot(4, 4, 5)
plt.plot(AS7262.dateTime, AS7262.yellowPre)
plt.xlabel('date/time')
plt.ylabel('yellowPre')
plt.subplot(4, 4, 6)
plt.plot(AS7262.dateTime, AS7262.orangePre)
plt.xlabel('date/time')
plt.ylabel('orangePre')
plt.subplot(4, 4, 7)
plt.plot(AS7262.dateTime, AS7262.redPre)
plt.xlabel('date/time')
plt.ylabel('redPre')
plt.subplot(4, 4, 8)
plt.plot(AS7262.dateTime, AS7262.violetCalibrated)
plt.xlabel('date/time')
plt.ylabel('violetCalibrated')
plt.subplot(4, 4, 9)
plt.plot(AS7262.dateTime, AS7262.blueCalibrated)
plt.xlabel('date/time')
plt.ylabel('blueCalibrated')
plt.subplot(4, 4, 10)
plt.plot(AS7262.dateTime, AS7262.greenCalibrated)
plt.xlabel('date/time')
plt.ylabel('greenCalibrated')
plt.subplot(4, 4, 11)
plt.plot(AS7262.dateTime, AS7262.yellowCalibrated)
plt.xlabel('date/time')
plt.ylabel('yellowCalibrated')
plt.subplot(4, 4, 12)
plt.plot(AS7262.dateTime, AS7262.orangeCalibrated)
plt.xlabel('date/time')
plt.ylabel('orangeCalibrated')
plt.subplot(4, 4, 13)
plt.plot(AS7262.dateTime, AS7262.redCalibrated)
plt.xlabel('date/time')
plt.ylabel('redCalibrated')
plt.show()

# %%
BME280.merge(IP)
# Out:
# Empty DataFrame
# Columns: [dateTime, temperature, pressure, humidity, altitude, publicIp, localIp]
# Index: []

# %%
BME280
# Out:
#                         dateTime  temperature  pressure  humidity  altitude
# 0     2021-06-09 00:00:02.863480        35.67   99302.0      50.0    169.78
# 1     2021-06-09 00:00:12.897674        35.67   99298.0      50.0    170.12
# 2     2021-06-09 00:00:22.932414        35.68   99296.0      50.0    170.28
# 3     2021-06-09 00:00:32.967237        35.67   99296.0      50.0    170.28
# 4     2021-06-09 00:00:43.002139        35.68   99299.0      50.0    170.03
# ...                          ...          ...       ...       ...       ...
# 5089  2021-06-09 14:13:03.188927        30.75   99765.0      64.0    130.68
# 5090  2021-06-09 14:13:13.223645        30.76   99767.0      64.0    130.51
# 5091  2021-06-09 14:13:23.258325        30.76   99769.0      64.0    130.34
# 5092  2021-06-09 14:13:33.293033        30.77   99769.0      64.0    130.34
# 5093  2021-06-09 14:13:43.327608        30.76   99769.0      64.0    130.34
#
# [5094 rows x 5 columns]

# %%
BME280.merge(IP)
# Out:
# Empty DataFrame
# Columns: [dateTime, temperature, pressure, humidity, altitude, publicIp, localIp]
# Index: []

# %%
lk=BME280.merge(IP)

# %%
lk
# Out:
# Empty DataFrame
# Columns: [dateTime, temperature, pressure, humidity, altitude, publicIp, localIp]
# Index: []

# %%
IP
# Out:
#                       dateTime         publicIp         localIp
# 0   2021-05-12 23:24:43.302727  129.110.242.173  192.168.20.121
# 1   2021-05-14 20:44:09.530530  129.110.242.173  192.168.20.121
# 2   2021-05-14 20:47:23.584828  129.110.242.173  192.168.20.121
# 3   2021-05-26 10:29:50.714791   107.77.197.165        10.0.4.2
# 4   2021-06-01 23:21:55.679721    107.77.199.70        10.0.4.2
# 5   2021-06-02 09:01:46.773605    107.77.198.40        10.0.4.2
# 6   2021-06-02 19:56:53.188368    107.77.198.40        10.0.4.2
# 7   2021-06-03 09:01:47.221298    107.77.198.40        10.0.4.2
# 8   2021-06-04 09:01:48.140693    107.77.196.94        10.0.4.2
# 9   2021-06-05 09:01:47.052176    107.77.196.94        10.0.4.2
# 10  2021-06-06 09:01:48.209190    107.77.196.94        10.0.4.2
# 11  2021-06-07 09:01:47.187854    107.77.196.94        10.0.4.2
# 12  2021-06-08 09:01:47.869330    107.77.196.94        10.0.4.2
# 13  2021-06-09 09:01:48.036841   107.77.200.201        10.0.4.2

# %%
BME280.merge(TMG3993)
# Out:
#                          dateTime_x  temperature  pressure  humidity  \
# 0        2021-06-09 00:00:02.863480        35.67   99302.0      50.0
# 1        2021-06-09 00:00:02.863480        35.67   99302.0      50.0
# 2        2021-06-09 00:00:02.863480        35.67   99302.0      50.0
# 3        2021-06-09 00:00:02.863480        35.67   99302.0      50.0
# 4        2021-06-09 00:00:02.863480        35.67   99302.0      50.0
# ...                             ...          ...       ...       ...
# 5746027  2021-06-09 14:13:43.327608        30.76   99769.0      64.0
# 5746028  2021-06-09 14:13:43.327608        30.76   99769.0      64.0
# 5746029  2021-06-09 14:13:43.327608        30.76   99769.0      64.0
# 5746030  2021-06-09 14:13:43.327608        30.76   99769.0      64.0
# 5746031  2021-06-09 14:13:43.327608        30.76   99769.0      64.0
#
#          altitude                  dateTime_y  infraRed    red  green   blue  \
# ...
